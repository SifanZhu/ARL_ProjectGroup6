# %%
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn

from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common import results_plotter

import matplotlib.pyplot as plt
import os
import yaml

import collections
import math

# %%
log_dir = "logs_nn"
os.makedirs(log_dir, exist_ok=True)

# %% [markdown]
# # Wrap Dynamic Model as Gym Environment

# %%
# ------------------------------------------------------------------
# Simple 3-Layer MLP
# ------------------------------------------------------------------
class MLP3(nn.Module):
    """A basic 3-layer perceptron: Input -> hidden1 -> hidden2 -> output.

    hidden_sizes: tuple (h1, h2)
    activation: callable returning nn.Module, e.g., nn.ReLU
    """
    def __init__(self, in_dim: int, out_dim: int, hidden_sizes=(128, 64), activation=nn.ReLU):
        super().__init__()
        h1, h2 = hidden_sizes
        self.net = nn.Sequential(
            nn.Linear(in_dim, h1),
            activation(),
            nn.Linear(h1, h2),
            activation(),
            nn.Linear(h2, out_dim),
        )

    def forward(self, x):
        return self.net(x)

class CartPoleNNEnv (gym.Env):
    
    def __init__(self, model_filename="dyn_model.pth", stats_filename="dyn_model_stats.yaml", window_size=4):
        self.dyn_model = torch.load(model_filename, weights_only=False)
        self.device = next(self.dyn_model.parameters()).device
        self.window_size=window_size

        # load normalization constants
        with open(stats_filename, 'r') as f:
            stats = yaml.safe_load(f)
    
        # Convert back to tensors
        self.x_mean = torch.tensor(stats['x_mean'], dtype=torch.float32).to(self.device)
        self.x_std  = torch.tensor(stats['x_std'], dtype=torch.float32).to(self.device)
        self.y_mean = torch.tensor(stats['y_mean'], dtype=torch.float32).to(self.device)
        self.y_std  = torch.tensor(stats['y_std'], dtype=torch.float32).to(self.device)
        
        # FIFO-buffer that keeps the neural state
        self.stateBuffer = collections.deque(maxlen=window_size)
        
        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        
        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array([self.x_threshold * 2,
                         np.finfo(np.float32).max,
                         self.theta_threshold_radians * 2,
                         np.finfo(np.float32).max],
                        dtype=np.float32)

        self.action_space = gym.spaces.Discrete(2)
        self.observation_space = gym.spaces.Box(-high, high, dtype=np.float32)

    def step (self, action):
        
        self.steps +=1
        
        # append last state + new action to state buffer
        netInput = [self.currentState[0], self.currentState[1],
                    self.currentState[2], self.currentState[3], 
                    action]
        self.stateBuffer.append (np.float64(netInput))
        state = np.array([list(self.stateBuffer)])
        
        # NN inference
        with torch.no_grad():
            state_tensor = torch.flatten(torch.tensor(state, dtype=torch.float32)).to(self.device)
            state_tensor_norm = (state_tensor - self.x_mean) / self.x_std
            y_pred_norm = self.dyn_model(state_tensor_norm)
            y_pred = y_pred_norm * self.y_std + self.y_mean
        netOutput = y_pred.squeeze(0).cpu().numpy()
                
        # retrieve new state
        self.currentState = np.float64([netOutput[0], netOutput[1], 
                                         netOutput[2], netOutput[3]])
        # check for episode termination
        cartPos = netOutput[0]
        pendPosDeg = np.degrees(netOutput[2])
        pendPosRad = netOutput[2]
        
        done=False
        if abs(cartPos) >= 2.4 or abs(pendPosDeg) >= 12 or self.steps > 200:
            done = True
            
        # compute reward
        rewardAngle = np.cos(pendPosRad)
        rewardPos = -abs(cartPos)
        
        return self.currentState, rewardAngle + rewardPos, done, False, {}
    
    def render (self):
        pass
    
    def reset(self, seed=0): 
        self.steps = 0
        
        # draw initial state
        initCartPos = 2. *np.random.random () - 1 # [-0.05, 0.05]
        initCartVel = 0
        initPendPos = 0
        initPendVel = 0
        
        # fill initial state
        for i in range (self.window_size):
            initState = np.float64([initCartPos, initCartVel, initPendPos, initPendVel, self.action_space.sample()])
            self.stateBuffer.append (initState)
            
        self.currentState = initState[0:4]
        
        return self.currentState, {}

# %% [markdown]
# # Instantiate monitored Gym environment

# %%
print("✓ CartPoleNNEnv environment class defined and ready for use")
# Out:
# ✓ CartPoleNNEnv environment class defined and ready for use

# %% [markdown]
# # Learn policy

# %% [markdown]
# ### 1) Callback function for saving best model during training

# %%
from stable_baselines3.common.callbacks import BaseCallback
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param avg_episodes: (int) average over the past n episodes (default: 100)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    :param vec_norm_env: (VecNormalize) stable-baselines VecNormalize object (contains Gym env)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1, avg_episodes=100, vec_norm_env=None):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model_nn')
        self.best_mean_reward = -np.inf
        self.best_timestep = -np.inf
        self.vec_norm_env = vec_norm_env
        self.avg_episodes = avg_episodes

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward - handle case where monitor files don't exist yet
            try:
                x, y = ts2xy(load_results(self.log_dir), 'timesteps')
            except Exception as e:
                # Monitor files not created yet, skip this callback check
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps} (waiting for monitor files...)")
                return True
            
            if len(x) > 0:
                # Mean training reward over the last avg_episodes episodes
                mean_reward = np.mean(y[-self.avg_episodes:])

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    self.best_timestep = self.num_timesteps
                    # Example for saving best model
                    if self.verbose > 0:
                        print("Saving new best model to {}".format(self.save_path))
                    self.model.save(self.save_path)
                    if self.vec_norm_env is not None: 
                        self.vec_norm_env.save ("%s.env_normalizations" % self.save_path)

                if self.verbose > 0:
                    print("Num timesteps: {}".format(self.num_timesteps))
                    print("Best mean reward: {:.2f} (ts={}) - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, self.best_timestep, mean_reward))


        return True

# %% [markdown]
# ### 2) Train Policy

# %%
# ============================================================================
# STEP 2: Train PPO Policy for Each Dynamic Model (N = 50, 100, 200, 500, 1000)
# ============================================================================
# Train one PPO policy per dynamic model with consistent hyperparameters

dataset_sizes = [50, 100, 200, 500, 1000]
time_steps = 101000  # Consistent training budget across all models

# Store results for comparison
ppo_results = {}

for N in dataset_sizes:
    print(f"\n{'='*80}")
    print(f"Training PPO Policy on Dynamic Model with N={N} episodes")
    print(f"{'='*80}")
    
    # 1. Create environment with corresponding dynamic model
    model_filename = f'model_N{N}.pth'
    stats_filename = f'dyn_model_stats_N{N}.yaml'
    
    env_single = CartPoleNNEnv(model_filename=model_filename, stats_filename=stats_filename, window_size=4)
    
    # 2. Setup monitoring and normalization
    log_dir_N = f"logs_nn_N{N}"
    os.makedirs(log_dir_N, exist_ok=True)  # Create log directory first
    
    env_monitored = Monitor(env_single, log_dir_N)
    env_vec = DummyVecEnv([lambda env=env_monitored: env])
    env_vec = VecNormalize(env_vec, norm_obs=True, norm_reward=True)
    
    # 3. Train PPO with identical hyperparameters
    model_ppo = PPO('MlpPolicy', env_vec, verbose=1)
    
    callback = SaveOnBestTrainingRewardCallback(
        check_freq=5000, 
        log_dir=log_dir_N, 
        avg_episodes=30, 
        vec_norm_env=env_vec
    )
    
    model_ppo.learn(total_timesteps=time_steps, callback=callback)
    
    # 4. Save results
    ppo_results[N] = {
        'model': model_ppo,
        'log_dir': log_dir_N,
        'env_stats': f"{log_dir_N}/best_model_nn.env_normalizations"
    }
    
    print(f"✓ PPO Policy trained for N={N} and saved to {log_dir_N}")
    
    env_vec.close()

print(f"\n{'='*80}")
print("All PPO policies trained successfully!")
print(f"{'='*80}")
# Out:
# ================================================================================
# Training PPO Policy on Dynamic Model with N=50 episodes
# ================================================================================
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.8     |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    fps             | 4144     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.8        |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 2908        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008461859 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.187      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0681      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.49        |
# -----------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 5000
# Best mean reward: 16.10 (ts=5000) - Last mean reward per episode: 16.10
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.9        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 2651        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014529744 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0684      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.1        |
# |    ep_rew_mean          | 27.7        |
# | time/                   |             |
# |    fps                  | 2563        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018681962 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 0.351       |
# -----------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 10000
# Best mean reward: 46.01 (ts=10000) - Last mean reward per episode: 46.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.6        |
# |    ep_rew_mean          | 36.5        |
# | time/                   |             |
# |    fps                  | 2504        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011294832 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 0.307       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.6        |
# |    ep_rew_mean          | 46.3        |
# | time/                   |             |
# |    fps                  | 2471        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011954788 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0262      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.9        |
# |    ep_rew_mean          | 55.5        |
# | time/                   |             |
# |    fps                  | 2452        |
# |    iterations           | 7           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008943288 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0865      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.228       |
# -----------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 15000
# Best mean reward: 89.75 (ts=15000) - Last mean reward per episode: 89.75
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.5        |
# |    ep_rew_mean          | 67.9        |
# | time/                   |             |
# |    fps                  | 2411        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006843348 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0583      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.244       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 77.3         |
# | time/                   |              |
# |    fps                  | 2396         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038256343 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.17         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.307        |
# ------------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 20000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 102.84
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 114          |
# |    ep_rew_mean          | 85.8         |
# | time/                   |              |
# |    fps                  | 2383         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0050476836 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.529       |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.229        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.233        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | 92.6         |
# | time/                   |              |
# |    fps                  | 2373         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035585205 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.065        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.236        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 95.6         |
# | time/                   |              |
# |    fps                  | 2364         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0033768092 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0278       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.194        |
# ------------------------------------------
# Num timesteps: 25000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 97.28
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 2359         |
# |    iterations           | 13           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0065140715 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 0.212        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | 91           |
# | time/                   |              |
# |    fps                  | 2357         |
# |    iterations           | 14           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0028327769 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0702       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.159        |
# ------------------------------------------
# Num timesteps: 30000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 90.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 121          |
# |    ep_rew_mean          | 88.1         |
# | time/                   |              |
# |    fps                  | 2355         |
# |    iterations           | 15           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0025502401 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.512       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00971      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000887    |
# |    value_loss           | 0.162        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 89.4        |
# | time/                   |             |
# |    fps                  | 2353        |
# |    iterations           | 16          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002074167 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 0.178       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 86           |
# | time/                   |              |
# |    fps                  | 2352         |
# |    iterations           | 17           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044585615 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0523       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 0.183        |
# ------------------------------------------
# Num timesteps: 35000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 77.56
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | 90.2         |
# | time/                   |              |
# |    fps                  | 2351         |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0021289792 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.517       |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0434       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 0.139        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 95.5        |
# | time/                   |             |
# |    fps                  | 2350        |
# |    iterations           | 19          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003546915 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0271      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.126       |
# -----------------------------------------
# Num timesteps: 40000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 89.87
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 95.5        |
# | time/                   |             |
# |    fps                  | 2349        |
# |    iterations           | 20          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004595356 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0619      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 87.9        |
# | time/                   |             |
# |    fps                  | 2349        |
# |    iterations           | 21          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004580741 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0939      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.115       |
# -----------------------------------------
# Num timesteps: 45000
# Best mean reward: 102.84 (ts=20000) - Last mean reward per episode: 79.37
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | 85.4         |
# | time/                   |              |
# |    fps                  | 2344         |
# |    iterations           | 22           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0029585452 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 0.158        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 92.4        |
# | time/                   |             |
# |    fps                  | 2343        |
# |    iterations           | 23          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005259059 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0838      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.0954      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 93.5         |
# | time/                   |              |
# |    fps                  | 2341         |
# |    iterations           | 24           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0027979603 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0612       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000696    |
# |    value_loss           | 0.156        |
# ------------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 50000
# Best mean reward: 105.67 (ts=50000) - Last mean reward per episode: 105.67
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | 92.1         |
# | time/                   |              |
# |    fps                  | 2341         |
# |    iterations           | 25           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0058253556 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0357       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 0.138        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 121          |
# |    ep_rew_mean          | 94.3         |
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 26           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0028111474 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0882       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00068     |
# |    value_loss           | 0.147        |
# ------------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 55000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 113.57
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 27           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0032328907 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.048        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000726    |
# |    value_loss           | 0.166        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 96.6         |
# | time/                   |              |
# |    fps                  | 2338         |
# |    iterations           | 28           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0030429973 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.101        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.171        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | 99          |
# | time/                   |             |
# |    fps                  | 2337        |
# |    iterations           | 29          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004680383 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0385      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 0.106       |
# -----------------------------------------
# Num timesteps: 60000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 96.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 2336        |
# |    iterations           | 30          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004749349 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | 99.8         |
# | time/                   |              |
# |    fps                  | 2331         |
# |    iterations           | 31           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0044173673 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.465       |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.116        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.174        |
# ------------------------------------------
# Num timesteps: 65000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 112.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 2328         |
# |    iterations           | 32           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0045409403 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 0.163        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 125        |
# |    ep_rew_mean          | 98.8       |
# | time/                   |            |
# |    fps                  | 2325       |
# |    iterations           | 33         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00414979 |
# |    clip_fraction        | 0.0577     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.486     |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0778     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00612   |
# |    value_loss           | 0.148      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 2323         |
# |    iterations           | 34           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0031025284 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0959       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 0.155        |
# ------------------------------------------
# Num timesteps: 70000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 112.35
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 136       |
# |    ep_rew_mean          | 109       |
# | time/                   |           |
# |    fps                  | 2320      |
# |    iterations           | 35        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0070866 |
# |    clip_fraction        | 0.0581    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.478    |
# |    explained_variance   | 0.897     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0209    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.00442  |
# |    value_loss           | 0.0769    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 2317        |
# |    iterations           | 36          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002000602 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0711      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -5.34e-05   |
# |    value_loss           | 0.152       |
# -----------------------------------------
# Num timesteps: 75000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 90.29
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 2313         |
# |    iterations           | 37           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0018754333 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0381       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.177        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 2311         |
# |    iterations           | 38           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0036882814 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.064        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 2311        |
# |    iterations           | 39          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.003477517 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000888   |
# |    value_loss           | 0.109       |
# -----------------------------------------
# Num timesteps: 80000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 112.81
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 2311        |
# |    iterations           | 40          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005802458 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0627      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 2311        |
# |    iterations           | 41          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.001827828 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0907      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000185   |
# |    value_loss           | 0.187       |
# -----------------------------------------
# Num timesteps: 85000
# Best mean reward: 113.57 (ts=55000) - Last mean reward per episode: 82.11
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 2310         |
# |    iterations           | 42           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0045680804 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0458       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 2311         |
# |    iterations           | 43           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0035907144 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0518       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 0.0965       |
# ------------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 90000
# Best mean reward: 115.46 (ts=90000) - Last mean reward per episode: 115.46
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 2312        |
# |    iterations           | 44          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005801007 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0496      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 2312         |
# |    iterations           | 45           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0061181206 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0977       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 0.115        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 2312         |
# |    iterations           | 46           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0043854713 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0184       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# Saving new best model to logs_nn_N50/best_model_nn
# Num timesteps: 95000
# Best mean reward: 123.06 (ts=95000) - Last mean reward per episode: 123.06
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 2311         |
# |    iterations           | 47           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0036423826 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0454       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 0.213        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 136          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 2311         |
# |    iterations           | 48           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0042319056 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0717       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.187        |
# ------------------------------------------
# Num timesteps: 100000
# Best mean reward: 123.06 (ts=95000) - Last mean reward per episode: 78.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 2311        |
# |    iterations           | 49          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002711393 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0632      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 0.152       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 2312        |
# |    iterations           | 50          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.003801307 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.057       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 0.144       |
# -----------------------------------------
# ✓ PPO Policy trained for N=50 and saved to logs_nn_N50
#
# ================================================================================
# Training PPO Policy on Dynamic Model with N=100 episodes
# ================================================================================
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    fps             | 4356     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 3055        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011537298 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.0474     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 10          |
# ...
# | time/                   |              |
# |    fps                  | 2369         |
# |    iterations           | 34           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0012959768 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000506    |
# |    value_loss           | 0.147        |
# ------------------------------------------
# Num timesteps: 70000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 113.80
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 2368         |
# |    iterations           | 35           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0037501405 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0587       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 0.11         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 2368        |
# |    iterations           | 36          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006234837 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0361      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 0.105       |
# -----------------------------------------
# Num timesteps: 75000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 95.75
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 2367         |
# |    iterations           | 37           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0051486725 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0575       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 0.124        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 2366         |
# |    iterations           | 38           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0055514527 |
# |    clip_fraction        | 0.0946       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.529        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0409       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 0.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 2363        |
# |    iterations           | 39          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002711752 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.419      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0775      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 0.122       |
# -----------------------------------------
# Num timesteps: 80000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 113.75
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 2362         |
# |    iterations           | 40           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0034415596 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.069        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 0.122        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 2361         |
# |    iterations           | 41           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0012332834 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0549       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0002      |
# |    value_loss           | 0.0913       |
# ------------------------------------------
# Num timesteps: 85000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 95.93
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 2360         |
# |    iterations           | 42           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0027375808 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0509       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 0.087        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 2359        |
# |    iterations           | 43          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002158677 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0817      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 0.0727      |
# -----------------------------------------
# Num timesteps: 90000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 97.19
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 2359        |
# |    iterations           | 44          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003951312 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0307      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 0.0901      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 2359         |
# |    iterations           | 45           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0040185996 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00424      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 0.0779       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 2358         |
# |    iterations           | 46           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0042897025 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0944       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 0.0974       |
# ------------------------------------------
# Num timesteps: 95000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 107.48
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 2358        |
# |    iterations           | 47          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002412919 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.093       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 2355         |
# |    iterations           | 48           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0033540833 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0236       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 0.075        |
# ------------------------------------------
# Num timesteps: 100000
# Best mean reward: 123.32 (ts=60000) - Last mean reward per episode: 113.58
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 2353        |
# |    iterations           | 49          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.003191391 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0943      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 2353        |
# |    iterations           | 50          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005484546 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0378      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 0.0761      |
# -----------------------------------------
# ✓ PPO Policy trained for N=1000 and saved to logs_nn_N1000
#
# ================================================================================
# All PPO policies trained successfully!
# ================================================================================

# %% [markdown]
# ### Plot

# %%
# Plot training results for all N values
fig, axes = plt.subplots(1, len(dataset_sizes), figsize=(16, 4))

for idx, N in enumerate(dataset_sizes):
    log_dir_N = f"logs_nn_N{N}"
    try:
        results_plotter.plot_results([log_dir_N], time_steps, results_plotter.X_TIMESTEPS, f"PPO CartPoleNN (N={N})")
        axes[idx].set_title(f"N={N} episodes")
        axes[idx].grid(True, alpha=0.3)
    except Exception as e:
        print(f"Could not plot results for N={N}: {e}")

plt.tight_layout()
plt.savefig("results-cartpoleNN-comparison.png", dpi=150)
plt.show()

print("✓ Results plots saved to results-cartpoleNN-comparison.png")
# Out:
# ✓ Results plots saved to results-cartpoleNN-comparison.png

# %% [markdown]
# # Model inference: Evaluate policy

# %% [markdown]
# ### load best policy

# %%
# Load all best trained policies
trained_policies = {}

for N in dataset_sizes:
    log_dir_N = f"logs_nn_N{N}"
    try:
        model_path = f"{log_dir_N}/best_model_nn.zip"
        model_ppo = PPO.load(model_path)
        trained_policies[N] = model_ppo
        print(f"✓ Loaded PPO policy for N={N} from {model_path}")
    except Exception as e:
        print(f"✗ Could not load policy for N={N}: {e}")
# Out:
# ✓ Loaded PPO policy for N=50 from logs_nn_N50/best_model_nn.zip
# ✓ Loaded PPO policy for N=100 from logs_nn_N100/best_model_nn.zip
# ✓ Loaded PPO policy for N=200 from logs_nn_N200/best_model_nn.zip
# ✓ Loaded PPO policy for N=500 from logs_nn_N500/best_model_nn.zip
# ✓ Loaded PPO policy for N=1000 from logs_nn_N1000/best_model_nn.zip

# %% [markdown]
# ### Evaluate on environment from where NN data was sampled from

# %%
# ============================================================================
# AUFGABE 3: Standardisierte Evaluation der Policies
# ============================================================================

# 3.1 Feste Startzustände definieren
# ============================================================================
print("\n" + "="*80)
print("AUFGABE 3.1: Define 20 Fixed Starting States")
print("="*80)

# Generate 20 different starting states using different seeds
num_starting_states = 20
starting_states = []

for seed in range(num_starting_states):
    env_temp = gym.make("CartPole-v1")
    state, _ = env_temp.reset(seed=seed)
    starting_states.append(state.copy())
    env_temp.close()

print(f"✓ Generated {len(starting_states)} fixed starting states")
print(f"  First state: {starting_states[0]}")
print(f"  Last state: {starting_states[-1]}")

# 3.2 & 3.3: Fair Evaluation - All Policies on Same Starting States
# ============================================================================
print("\n" + "="*80)
print("AUFGABE 3.2 & 3.3: Fair Comparison with Standardized Evaluation")
print("="*80)

evaluation_results = {}

for N in dataset_sizes:
    if N not in trained_policies:
        print(f"⚠ Policy for N={N} not available, skipping evaluation")
        continue
    
    print(f"\nEvaluating policy trained on N={N} dynamic model...")
    print(f"  Testing on {num_starting_states} standardized starting states...")
    
    # Create real CartPole environment (no normalization wrapper for this evaluation)
    env_real = gym.make("CartPole-v1", render_mode=None)
    
    # Evaluate on all 20 starting states
    episode_lengths = []
    episode_rewards = []
    
    for state_idx, initial_state in enumerate(starting_states):
        # Call reset() first to satisfy TimeLimit wrapper, then set our desired state
        env_real.reset()
        env_real.unwrapped.state = initial_state.copy()
        state = initial_state.copy()
        done = False
        episode_length = 0
        episode_reward = 0.0
        
        while not done and episode_length < 500:  # CartPole max length is 500
            episode_length += 1
            
            # Get action from policy (without normalization, using raw state)
            action, _states = trained_policies[N].predict(state, deterministic=True)
            
            # Take step in environment
            state, reward, terminated, truncated, _ = env_real.step(action)
            done = terminated or truncated
            episode_reward += reward
        
        episode_lengths.append(episode_length)
        episode_rewards.append(episode_reward)
    
    # Calculate statistics
    avg_length = np.mean(episode_lengths)
    std_length = np.std(episode_lengths)
    max_length = np.max(episode_lengths)
    min_length = np.min(episode_lengths)
    avg_reward = np.mean(episode_rewards)
    
    evaluation_results[N] = {
        'lengths': episode_lengths,
        'rewards': episode_rewards,
        'avg_length': avg_length,
        'std_length': std_length,
        'max_length': max_length,
        'min_length': min_length,
        'avg_reward': avg_reward
    }
    
    print(f"  ✓ Results for N={N}:")
    print(f"    Average episode length: {avg_length:.2f} ± {std_length:.2f} steps")
    print(f"    Range: {min_length:.0f} - {max_length:.0f} steps")
    print(f"    Average reward: {avg_reward:.2f}")
    
    env_real.close()

# Print comprehensive comparison table
print(f"\n{'='*80}")
print("EVALUATION SUMMARY - Standardized Comparison")
print(f"{'='*80}")
print(f"{'N':>6} | {'Avg Length':>12} | {'Std Dev':>10} | {'Max':>6} | {'Min':>6} | {'Avg Reward':>12}")
print("-" * 70)

for N in dataset_sizes:
    if N in evaluation_results:
        r = evaluation_results[N]
        print(f"{N:>6} | {r['avg_length']:>12.2f} | {r['std_length']:>10.2f} | {r['max_length']:>6.0f} | {r['min_length']:>6.0f} | {r['avg_reward']:>12.2f}")

# Ranking
print(f"\n{'='*80}")
print("PERFORMANCE RANKING")
print(f"{'='*80}")

ranking = sorted(evaluation_results.items(), key=lambda x: x[1]['avg_length'], reverse=True)
for rank, (N, results) in enumerate(ranking, 1):
    print(f"{rank}. N={N:4d}: {results['avg_length']:6.2f} avg steps (σ={results['std_length']:5.2f})")
# Out:
# ================================================================================
# AUFGABE 3.1: Define 20 Fixed Starting States
# ================================================================================
# ✓ Generated 20 fixed starting states
#   First state: [ 0.01369617 -0.02302133 -0.04590265 -0.04834723]
#   Last state: [-0.00796212  0.04258693 -0.022613   -0.04399514]
#
# ================================================================================
# AUFGABE 3.2 & 3.3: Fair Comparison with Standardized Evaluation
# ================================================================================
#
# Evaluating policy trained on N=50 dynamic model...
#   Testing on 20 standardized starting states...
#   ✓ Results for N=50:
#     Average episode length: 500.00 ± 0.00 steps
#     Range: 500 - 500 steps
#     Average reward: 500.00
#
# Evaluating policy trained on N=100 dynamic model...
#   Testing on 20 standardized starting states...
#   ✓ Results for N=100:
#     Average episode length: 63.85 ± 5.45 steps
#     Range: 56 - 80 steps
#     Average reward: 63.85
#
# Evaluating policy trained on N=200 dynamic model...
#   Testing on 20 standardized starting states...
#   ✓ Results for N=200:
#     Average episode length: 55.15 ± 9.49 steps
#     Range: 47 - 89 steps
#     Average reward: 55.15
#
# Evaluating policy trained on N=500 dynamic model...
#   Testing on 20 standardized starting states...
#   ✓ Results for N=500:
#     Average episode length: 71.60 ± 13.46 steps
#     Range: 42 - 94 steps
#     Average reward: 71.60
#
# Evaluating policy trained on N=1000 dynamic model...
#   Testing on 20 standardized starting states...
#   ✓ Results for N=1000:
#     Average episode length: 39.85 ± 11.16 steps
#     Range: 20 - 51 steps
#     Average reward: 39.85
#
# ================================================================================
# EVALUATION SUMMARY - Standardized Comparison
# ================================================================================
#      N |   Avg Length |    Std Dev |    Max |    Min |   Avg Reward
# ----------------------------------------------------------------------
#     50 |       500.00 |       0.00 |    500 |    500 |       500.00
#    100 |        63.85 |       5.45 |     80 |     56 |        63.85
#    200 |        55.15 |       9.49 |     89 |     47 |        55.15
#    500 |        71.60 |      13.46 |     94 |     42 |        71.60
#   1000 |        39.85 |      11.16 |     51 |     20 |        39.85
#
# ================================================================================
# PERFORMANCE RANKING
# ================================================================================
# 1. N=  50: 500.00 avg steps (σ= 0.00)
# 2. N= 500:  71.60 avg steps (σ=13.46)
# 3. N= 100:  63.85 avg steps (σ= 5.45)
# 4. N= 200:  55.15 avg steps (σ= 9.49)
# 5. N=1000:  39.85 avg steps (σ=11.16)
